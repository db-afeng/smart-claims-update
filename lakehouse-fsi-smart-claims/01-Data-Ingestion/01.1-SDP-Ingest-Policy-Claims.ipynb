# %% [markdown]
# # Policy, Claims & Telematics SDP Ingestion pipeline
#
# <img src="https://github.com/databricks-demos/dbdemos-resources/blob/main/images/fsi/smart-claims/fsi-claims-dlt-0.png?raw=true" style="float: right" width="800px">
#
# Using <b>Spark Declarative Pipelines</b> (SDP) for ETL helps simplify and operationalize the pipeline with its support for autoloader, data quality via constraints, efficient auto-scaling for streaming workloads, resiliency via restart on failure, execution of administrative operations among others.
#
# We'll show how Databricks makes it easy to incrementally ingest and transform our incoming claims data.
#
# For more advanced SDP capabilities run `dbdemos.install('pipeline-bikes')` or `dbdemos.install('declarative-pipeline-cdc')` for CDC/SCDT2 example.
#
#
#
# ## Ingestion made it easy with Databricks Assistant
#
# Databricks Data Intelligent Platform simplify our journey, empowering Data Analyst to do more and build robust Data Pipelines.
#
# Questions can be asked in plain text to our assistant, which will suggest how to build the pipeline, fix bug and offer potential improvements.
#
# <!-- Collect usage data (view). Remove it to disable collection or disable tracker during installation. View README for more details.  -->
# <img width="1px" src="https://ppxrzfxige.execute-api.us-west-2.amazonaws.com/v1/analytics?category=lakehouse&org_id=1444828305810485&notebook=%2F01-Data-Ingestion%2F01.1-DLT-Ingest-Policy-Claims&demo_name=lakehouse-fsi-smart-claims&event=VIEW&path=%2F_dbdemos%2Flakehouse%2Flakehouse-fsi-smart-claims%2F01-Data-Ingestion%2F01.1-DLT-Ingest-Policy-Claims&version=1&user_hash=1868b144de45687ae4c3cc1223c535cf80acd3c5475593edeb5b8d2642fab04a">

# %% [markdown]
# This demo started for you a <a dbdemos-pipeline-id="sdp-fsi-smart-claims" href="#joblist/pipelines/71c6a196-0e74-4e44-86bc-314cf4063cfd" target="_blank">SDP Pipeline</a> Explore it to see its execution out of the box.

# %% [markdown]
# #### 1/ Exploring the data
# First, open the [notebook in the Exploration folder]($./explorations/01-Exploring-the-Data) to discover our dataset.
#
# We'll consume data from 4 sources, all available to us as raw CSV or JSON file in our schema volume:
#
# - **maintenance_logs** (all the maintenance details, as csv files)
# - **rides** (the ride informations, including comments from users using the mobile application)
# - **weather** (current and forecast, as JSON file)
# - **customers** (customer CDC data for Auto CDC processing, as parquet files)

# %% [markdown]
# #### 2/ Get started with Streaming Tables and Materialized view
#
# Creating your pipeline is super simple! If you're new to the Declarative Pipelines, it's best to start with the [UI introduction from the documentation](https://docs.databricks.com/aws/en/dlt/dlt-multi-file-editor)!
#
#
#
# **Your Lakeflow Declarative Pipeline has been installed and started for you!** Open the <a dbdemos-pipeline-id="sdp-fsi-smart-claims" href="#joblist/pipelines/71c6a196-0e74-4e44-86bc-314cf4063cfd" target="_blank">Smart Claims Pipeline</a>
# *(Note: The pipeline will automatically start once the initialization job is completed, this might take a few minutes... Check installation logs for more details)*

# %% [markdown]
# #### 3/ Ingesting and transforming your data
#
# Now that we reviewed the data available to us, it's time to start creating our pipeline! We'll do it one step at a time.
#
# Open the [00-pipeline-tutorial notebook]($./transformations/00-pipeline-tutorial) to get started.
